# %% [markdown]
# # Import libraries

# %%
# for requesting data from Yahoo Finance API and NASDAQ API
import json
import ast
import requests
from requests.exceptions import Timeout
from config import x_rapidapi_key, x_rapidapi_host

# for data extraction and analyses
import pandas as pd
from pandas.io.json import json_normalize
from datetime import datetime

# for data visualisation
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# # Collecting financial data for stocks

# %%
# data source URL for list of ticker symbols from NASDAQ:
# "https://api.nasdaq.com/api/screener/stocks?tableonly=true&limit=25&offset=0&download=true"
# data copied and pasted from URL to tickers.txt (dictionary string) but will write code to automate pulling data from URL
tickers = open("tickers.txt", "r")
contents = tickers.read()
contents = contents[:2429232]

# convert dictionary string to dictionary
ticker_dict = json.loads(contents)
ticker_dict
# Out:
# {'data': {'headers': {'symbol': 'Symbol',
#    'name': 'Name',
#    'lastsale': 'Last Sale',
#    'netchange': 'Net Change',
#    'pctchange': '% Change',
#    'marketCap': 'Market Cap',
#    'country': 'Country',
#    'ipoyear': 'IPO Year',
#    'volume': 'Volume',
#    'sector': 'Sector',
#    'industry': 'Industry',
#    'url': 'Url'},
#   'rows': [{'symbol': 'A',
#     'name': 'Agilent Technologies Inc. Common Stock',
#     'lastsale': '$149.27',
#     'netchange': '-0.24',
#     'pctchange': '-0.161%',
#     'volume': '1456502',
#     'marketCap': '45294970196.00',
#     'country': 'United States',
#     'ipoyear': '1999',
#     'industry': 'Electrical Products',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/a'},
#    {'symbol': 'AA',
#     'name': 'Alcoa Corporation Common Stock ',
#     'lastsale': '$35.62',
#     'netchange': '-1.67',
#     'pctchange': '-4.478%',
#     'volume': '8066765',
#     'marketCap': '6651135417.00',
#     'country': '',
#     'ipoyear': '2016',
#     'industry': 'Metal Fabrications',
#     'sector': 'Basic Industries',
#     'url': '/market-activity/stocks/aa'},
#    {'symbol': 'AAC',
#     'name': 'Ares Acquisition Corporation Class A Ordinary Shares',
#     'lastsale': '$9.81',
#     'netchange': '0.01',
#     'pctchange': '0.102%',
#     'volume': '284083',
#     'marketCap': '1226250000.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/aac'},
#    {'symbol': 'AACG',
#     'name': 'ATA Creativity Global American Depositary Shares',
#     'lastsale': '$2.80',
#     'netchange': '-0.07',
#     'pctchange': '-2.439%',
#     'volume': '40463',
#     'marketCap': '88763326.00',
#     'country': 'China',
#     'ipoyear': '',
#     'industry': 'Service to the Health Industry',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/aacg'},
#    {'symbol': 'AAIC',
#     'name': 'Arlington Asset Investment Corp Class A (new)',
#     'lastsale': '$3.81',
#     'netchange': '-0.14',
#     'pctchange': '-3.544%',
#     'volume': '287565',
#     'marketCap': '127563300.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Finance/Investors Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/aaic'},
#    {'symbol': 'AAIC^B',
#     'name': 'Arlington Asset Investment Corp 7.00% ',
#     'lastsale': '$25.25',
#     'netchange': '-0.08',
#     'pctchange': '-0.316%',
#     'volume': '885',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/aaic^b'},
#    {'symbol': 'AAIC^C',
#     'name': 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   ',
#     'lastsale': '$25.39',
#     'netchange': '0.16',
#     'pctchange': '0.634%',
#     'volume': '396',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/aaic^c'},
#    {'symbol': 'AAL',
#     'name': 'American Airlines Group Inc. Common Stock',
#     'lastsale': '$20.02',
#     'netchange': '-0.82',
#     'pctchange': '-3.935%',
#     'volume': '30714508',
#     'marketCap': '12840490122.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Air Freight/Delivery Services',
#     'sector': 'Transportation',
#     'url': '/market-activity/stocks/aal'},
#    {'symbol': 'AAMC',
#     'name': 'Altisource Asset Management Corp Com',
#     'lastsale': '$17.54',
#     'netchange': '0.0173',
#     'pctchange': '0.099%',
#     'volume': '1103',
#     'marketCap': '35927515.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Investment Managers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/aamc'},
#    {'symbol': 'AAME',
#     'name': 'Atlantic American Corporation Common Stock',
#     'lastsale': '$4.38',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '16370',
#     'marketCap': '89421125.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Life Insurance',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/aame'},
#    {'symbol': 'AAN',
#     'name': 'Aarons Holdings Company Inc. Common Stock ',
#     'lastsale': '$29.40',
#     'netchange': '-1.55',
#     'pctchange': '-5.008%',
#     'volume': '289736',
#     'marketCap': '1056423056.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Diversified Commercial Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/aan'},
#    {'symbol': 'AAOI',
#     'name': 'Applied Optoelectronics Inc. Common Stock',
#     'lastsale': '$7.83',
#     'netchange': '-0.125',
#     'pctchange': '-1.571%',
#     'volume': '248696',
#     'marketCap': '210330149.00',
#     'country': 'United States',
#     'ipoyear': '2013',
#     'industry': 'Semiconductors',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/aaoi'},
#    {'symbol': 'AAON',
#     'name': 'AAON Inc. Common Stock',
#     'lastsale': '$61.52',
#     'netchange': '-1.14',
#     'pctchange': '-1.819%',
#     'volume': '76577',
#     'marketCap': '3225811474.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Industrial Machinery/Components',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/aaon'},
#    {'symbol': 'AAP',
#     'name': 'Advance Auto Parts Inc Advance Auto Parts Inc W/I',
#     'lastsale': '$208.97',
#     'netchange': '-2.96',
#     'pctchange': '-1.397%',
#     'volume': '688982',
#     'marketCap': '13674760664.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Other Specialty Stores',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/aap'},
#    {'symbol': 'AAPL',
#     'name': 'Apple Inc. Common Stock',
#     'lastsale': '$145.64',
#     'netchange': '1.14',
#     'pctchange': '0.789%',
#     'volume': '100697717',
#     'marketCap': '2525010197600.00',
#     'country': 'United States',
#     'ipoyear': '1980',
#     'industry': 'Computer Manufacturing',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/aapl'},
#    {'symbol': 'AAQC',
#     'name': 'Accelerate Acquisition Corp. Class A Common Stock',
#     'lastsale': '$9.70',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '202',
#     'marketCap': '485000000.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/aaqc'},
#    {'symbol': 'AAT',
#     'name': 'American Assets Trust Inc. Common Stock',
#     'lastsale': '$36.95',
#     'netchange': '-1.09',
#     'pctchange': '-2.865%',
#     'volume': '288573',
#     'marketCap': '2234450968.00',
#     'country': 'United States',
#     'ipoyear': '2011',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/aat'},
#    {'symbol': 'AAU',
#     'name': 'Almaden Minerals Ltd. Common Shares',
#     'lastsale': '$0.4713',
#     'netchange': '-0.0107',
#     'pctchange': '-2.22%',
#     'volume': '346351',
#     'marketCap': '64672450.00',
#     'country': 'Canada',
#     'ipoyear': '2015',
#     'industry': 'Precious Metals',
#     'sector': 'Basic Industries',
#     'url': '/market-activity/stocks/aau'},
#    {'symbol': 'AAWW',
#     'name': 'Atlas Air Worldwide Holdings NEW Common Stock',
#     'lastsale': '$66.30',
#     'netchange': '-1.49',
#     'pctchange': '-2.198%',
#     'volume': '334568',
#     'marketCap': '1923284435.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Transportation Services',
#     'sector': 'Transportation',
#     'url': '/market-activity/stocks/aaww'},
#    {'symbol': 'AB',
#     'name': 'AllianceBernstein Holding L.P.  Units',
#     'lastsale': '$45.72',
#     'netchange': '-0.92',
#     'pctchange': '-1.973%',
#     'volume': '209325',
#     'marketCap': '4594395896.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Investment Managers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/ab'},
#    {'symbol': 'ABB',
#     'name': 'ABB Ltd Common Stock',
#     'lastsale': '$35.71',
#     'netchange': '-0.25',
#     'pctchange': '-0.695%',
#     'volume': '929915',
#     'marketCap': '71777254089.00',
#     'country': 'Switzerland',
#     'ipoyear': '',
#     'industry': 'Electrical Products',
#     'sector': 'Consumer Durables',
#     'url': '/market-activity/stocks/abb'},
#    {'symbol': 'ABBV',
#     'name': 'AbbVie Inc. Common Stock',
#     'lastsale': '$117.91',
#     'netchange': '0.28',
#     'pctchange': '0.238%',
#     'volume': '6537424',
#     'marketCap': '208255275638.00',
#     'country': 'United States',
#     'ipoyear': '2012',
#     'industry': 'Other Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abbv'},
#    {'symbol': 'ABC',
#     'name': 'AmerisourceBergen Corporation Common Stock',
#     'lastsale': '$114.21',
#     'netchange': '-1.34',
#     'pctchange': '-1.16%',
#     'volume': '846696',
#     'marketCap': '23688377989.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Other Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abc'},
#    {'symbol': 'ABCB',
#     'name': 'Ameris Bancorp Common Stock',
#     'lastsale': '$48.54',
#     'netchange': '-1.27',
#     'pctchange': '-2.55%',
#     'volume': '324729',
#     'marketCap': '3384763418.00',
#     'country': 'United States',
#     'ipoyear': '1994',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/abcb'},
#    {'symbol': 'ABCL',
#     'name': 'AbCellera Biologics Inc. Common Shares',
#     'lastsale': '$17.83',
#     'netchange': '-0.82',
#     'pctchange': '-4.397%',
#     'volume': '1620921',
#     'marketCap': '4830608583.00',
#     'country': 'Canada',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/abcl'},
#    {'symbol': 'ABCM',
#     'name': 'Abcam plc American Depositary Shares',
#     'lastsale': '$18.75',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '141353',
#     'marketCap': '4251519731.00',
#     'country': 'United Kingdom',
#     'ipoyear': '2020',
#     'industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abcm'},
#    {'symbol': 'ABEO',
#     'name': 'Abeona Therapeutics Inc. Common Stock',
#     'lastsale': '$1.38',
#     'netchange': '-0.04',
#     'pctchange': '-2.817%',
#     'volume': '1092189',
#     'marketCap': '137851880.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abeo'},
#    {'symbol': 'ABEV',
#     'name': 'Ambev S.A. American Depositary Shares (Each representing 1 Common Share)',
#     'lastsale': '$3.44',
#     'netchange': '0.03',
#     'pctchange': '0.88%',
#     'volume': '30535404',
#     'marketCap': '54134960703.00',
#     'country': '',
#     'ipoyear': '2013',
#     'industry': 'Beverages (Production/Distribution)',
#     'sector': 'Consumer Non-Durables',
#     'url': '/market-activity/stocks/abev'},
#    {'symbol': 'ABG',
#     'name': 'Asbury Automotive Group Inc Common Stock',
#     'lastsale': '$189.22',
#     'netchange': '1.69',
#     'pctchange': '0.901%',
#     'volume': '249712',
#     'marketCap': '3659383481.00',
#     'country': 'United States',
#     'ipoyear': '2002',
#     'industry': 'Other Specialty Stores',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/abg'},
#    {'symbol': 'ABGI',
#     'name': 'ABG Acquisition Corp. I Class A Ordinary Shares',
#     'lastsale': '$9.88',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '35',
#     'marketCap': '191005594.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/abgi'},
#    {'symbol': 'ABIO',
#     'name': 'ARCA biopharma Inc. Common Stock',
#     'lastsale': '$3.17',
#     'netchange': '-0.52',
#     'pctchange': '-14.092%',
#     'volume': '709146',
#     'marketCap': '45680153.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Biotechnology: In Vitro & In Vivo Diagnostic Substances',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abio'},
#    {'symbol': 'ABM',
#     'name': 'ABM Industries Incorporated Common Stock',
#     'lastsale': '$44.10',
#     'netchange': '-0.14',
#     'pctchange': '-0.316%',
#     'volume': '549741',
#     'marketCap': '2960490595.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Diversified Commercial Services',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/abm'},
#    {'symbol': 'ABMD',
#     'name': 'ABIOMED Inc. Common Stock',
#     'lastsale': '$319.13',
#     'netchange': '-3.01',
#     'pctchange': '-0.934%',
#     'volume': '137016',
#     'marketCap': '14470935808.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Medical/Dental Instruments',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abmd'},
#    {'symbol': 'ABNB',
#     'name': 'Airbnb Inc. Class A Common Stock',
#     'lastsale': '$143.41',
#     'netchange': '-3.28',
#     'pctchange': '-2.236%',
#     'volume': '5863168',
#     'marketCap': '85529581594.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Diversified Commercial Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/abnb'},
#    {'symbol': 'ABOS',
#     'name': 'Acumen Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$18.94',
#     'netchange': '0.44',
#     'pctchange': '2.378%',
#     'volume': '81197',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/abos'},
#    {'symbol': 'ABR',
#     'name': 'Arbor Realty Trust Common Stock',
#     'lastsale': '$17.99',
#     'netchange': '-0.29',
#     'pctchange': '-1.586%',
#     'volume': '1018834',
#     'marketCap': '2559322326.00',
#     'country': 'United States',
#     'ipoyear': '2004',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/abr'},
#    {'symbol': 'ABR^D',
#     'name': 'Arbor Realty Trust 6.375% Series D Cumulative Redeemable Preferred Stock Liquidation Preference $25.00 per Share',
#     'lastsale': '$25.55',
#     'netchange': '-0.09',
#     'pctchange': '-0.351%',
#     'volume': '50189',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/abr^d'},
#    {'symbol': 'ABST',
#     'name': 'Absolute Software Corporation Common Stock',
#     'lastsale': '$14.03',
#     'netchange': '-0.12',
#     'pctchange': '-0.848%',
#     'volume': '62233',
#     'marketCap': '694633536.00',
#     'country': 'Canada',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/abst'},
#    {'symbol': 'ABT',
#     'name': 'Abbott Laboratories Common Stock',
#     'lastsale': '$118.65',
#     'netchange': '-0.16',
#     'pctchange': '-0.135%',
#     'volume': '3877091',
#     'marketCap': '210819710560.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Medical/Dental Instruments',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/abt'},
#    {'symbol': 'ABTX',
#     'name': 'Allegiance Bancshares Inc. Common Stock',
#     'lastsale': '$36.55',
#     'netchange': '-1.09',
#     'pctchange': '-2.896%',
#     'volume': '48040',
#     'marketCap': '737689198.00',
#     'country': 'United States',
#     'ipoyear': '2015',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/abtx'},
#    {'symbol': 'ABUS',
#     'name': 'Arbutus Biopharma Corporation Common Stock',
#     'lastsale': '$2.84',
#     'netchange': '-0.04',
#     'pctchange': '-1.389%',
#     'volume': '2147372',
#     'marketCap': '277046967.00',
#     'country': 'Canada',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/abus'},
#    {'symbol': 'AC',
#     'name': 'Associated Capital Group Inc. Common Stock',
#     'lastsale': '$39.50',
#     'netchange': '-0.08',
#     'pctchange': '-0.202%',
#     'volume': '16787',
#     'marketCap': '873781278.00',
#     'country': 'United States',
#     'ipoyear': '2015',
#     'industry': 'Investment Bankers/Brokers/Service',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/ac'},
#    {'symbol': 'ACA',
#     'name': 'Arcosa Inc. Common Stock ',
#     'lastsale': '$55.36',
#     'netchange': '-1.00',
#     'pctchange': '-1.774%',
#     'volume': '103796',
#     'marketCap': '2666922716.00',
#     'country': '',
#     'ipoyear': '2018',
#     'industry': 'Industrial Machinery/Components',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/aca'},
#    {'symbol': 'ACAD',
#     'name': 'ACADIA Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$23.98',
#     'netchange': '0.24',
#     'pctchange': '1.011%',
#     'volume': '1514125',
#     'marketCap': '3841093283.00',
#     'country': 'United States',
#     'ipoyear': '1985',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/acad'},
#    {'symbol': 'ACAH',
#     'name': 'Atlantic Coastal Acquisition Corp. Class A Common Stock',
#     'lastsale': '$9.64',
#     'netchange': '-0.04',
#     'pctchange': '-0.413%',
#     'volume': '15554',
#     'marketCap': '415725000.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acah'},
#    {'symbol': 'ACAHU',
#     'name': 'Atlantic Coastal Acquisition Corp. Unit',
#     'lastsale': '$10.00',
#     'netchange': '0.04',
#     'pctchange': '0.402%',
#     'volume': '34249',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acahu'},
#    {'symbol': 'ACAHW',
#     'name': 'Atlantic Coastal Acquisition Corp. Warrant',
#     'lastsale': '$0.951',
#     'netchange': '0.001',
#     'pctchange': '0.105%',
#     'volume': '1947',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acahw'},
#    {'symbol': 'ACB',
#     'name': 'Aurora Cannabis Inc. Common Shares',
#     'lastsale': '$8.37',
#     'netchange': '0.04',
#     'pctchange': '0.48%',
#     'volume': '5020462',
#     'marketCap': '1657090449.00',
#     'country': 'Canada',
#     'ipoyear': '',
#     'industry': 'Specialty Chemicals',
#     'sector': 'Consumer Durables',
#     'url': '/market-activity/stocks/acb'},
#    {'symbol': 'ACBA',
#     'name': 'Ace Global Business Acquisition Limited Ordinary Shares',
#     'lastsale': '$10.05',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '37',
#     'marketCap': '60842700.00',
#     'country': 'Hong Kong',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/acba'},
#    {'symbol': 'ACBAU',
#     'name': 'Ace Global Business Acquisition Limited Unit',
#     'lastsale': '$11.22',
#     'netchange': '0.6164',
#     'pctchange': '5.813%',
#     'volume': '1353',
#     'marketCap': '0.00',
#     'country': 'Hong Kong',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/acbau'},
#    {'symbol': 'ACBAW',
#     'name': 'Ace Global Business Acquisition Limited Warrant',
#     'lastsale': '$0.67',
#     'netchange': '0.06',
#     'pctchange': '9.836%',
#     'volume': '10673',
#     'marketCap': '0.00',
#     'country': 'Hong Kong',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/acbaw'},
#    {'symbol': 'ACBI',
#     'name': 'Atlantic Capital Bancshares Inc. Common Stock',
#     'lastsale': '$24.39',
#     'netchange': '-0.24',
#     'pctchange': '-0.974%',
#     'volume': '48804',
#     'marketCap': '495922016.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acbi'},
#    {'symbol': 'ACC',
#     'name': 'American Campus Communities Inc Common Stock',
#     'lastsale': '$49.07',
#     'netchange': '-0.68',
#     'pctchange': '-1.367%',
#     'volume': '648721',
#     'marketCap': '6765074413.00',
#     'country': 'United States',
#     'ipoyear': '2004',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acc'},
#    {'symbol': 'ACCD',
#     'name': 'Accolade Inc. Common Stock',
#     'lastsale': '$53.29',
#     'netchange': '-0.91',
#     'pctchange': '-1.679%',
#     'volume': '290435',
#     'marketCap': '3519116793.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/accd'},
#    {'symbol': 'ACCO',
#     'name': 'Acco Brands Corporation Common Stock',
#     'lastsale': '$8.26',
#     'netchange': '-0.12',
#     'pctchange': '-1.432%',
#     'volume': '299868',
#     'marketCap': '788762739.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Advertising',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acco'},
#    {'symbol': 'ACEL',
#     'name': 'Accel Entertainment Inc. ',
#     'lastsale': '$11.05',
#     'netchange': '-0.02',
#     'pctchange': '-0.181%',
#     'volume': '150103',
#     'marketCap': '1031957522.00',
#     'country': 'United States',
#     'ipoyear': '2017',
#     'industry': 'Recreational Products/Toys',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acel'},
#    {'symbol': 'ACER',
#     'name': 'Acer Therapeutics Inc. Common Stock (DE)',
#     'lastsale': '$2.53',
#     'netchange': '-0.04',
#     'pctchange': '-1.556%',
#     'volume': '61260',
#     'marketCap': '36204917.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/acer'},
#    {'symbol': 'ACET',
#     'name': 'Adicet Bio Inc. Common Stock ',
#     'lastsale': '$8.50',
#     'netchange': '-0.50',
#     'pctchange': '-5.556%',
#     'volume': '62854',
#     'marketCap': '166513538.00',
#     'country': 'United States',
#     'ipoyear': '2018',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/acet'},
#    {'symbol': 'ACEV',
#     'name': 'ACE Convergence Acquisition Corp. Class A Ordinary Shares',
#     'lastsale': '$9.85',
#     'netchange': '-0.01',
#     'pctchange': '-0.101%',
#     'volume': '1903019',
#     'marketCap': '283187500.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Semiconductors',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acev'},
#    {'symbol': 'ACEVU',
#     'name': 'ACE Convergence Acquisition Corp. Unit',
#     'lastsale': '$10.20',
#     'netchange': '-0.0201',
#     'pctchange': '-0.197%',
#     'volume': '5101',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Semiconductors',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acevu'},
#    {'symbol': 'ACEVW',
#     'name': 'ACE Convergence Acquisition Corp. Warrant',
#     'lastsale': '$0.80',
#     'netchange': '-0.02',
#     'pctchange': '-2.439%',
#     'volume': '283602',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Semiconductors',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acevw'},
#    {'symbol': 'ACGL',
#     'name': 'Arch Capital Group Ltd. Common Stock',
#     'lastsale': '$37.54',
#     'netchange': '-0.84',
#     'pctchange': '-2.189%',
#     'volume': '1091726',
#     'marketCap': '15151860301.00',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': 'Property-Casualty Insurers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acgl'},
#    {'symbol': 'ACGLN',
#     'name': 'Arch Capital Group Ltd. Depositary Shares each Representing a 1/1000th Interest in a 4.550% Non-Cumulative Preferred Share Series G',
#     'lastsale': '$25.78',
#     'netchange': '-0.03',
#     'pctchange': '-0.116%',
#     'volume': '509894',
#     'marketCap': '0.00',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': 'Property-Casualty Insurers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acgln'},
#    {'symbol': 'ACGLO',
#     'name': 'Arch Capital Group Ltd. Depositary Shares Each Representing 1/1000th Interest in a Share of 5.45% Non-Cumulative Preferred Shares Series F',
#     'lastsale': '$26.16',
#     'netchange': '-0.0707',
#     'pctchange': '-0.27%',
#     'volume': '24836',
#     'marketCap': '0.00',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': 'Property-Casualty Insurers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acglo'},
#    {'symbol': 'ACGLP',
#     'name': 'Arch Capital Group Ltd. Depositary Shares Representing Interest in 5.25% Non-Cumulative Preferred Series E Shrs',
#     'lastsale': '$25.35',
#     'netchange': '-0.03',
#     'pctchange': '-0.118%',
#     'volume': '31194',
#     'marketCap': '0.00',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': 'Property-Casualty Insurers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acglp'},
#    {'symbol': 'ACH',
#     'name': 'Aluminum Corporation of China Limited American Depositary Shares',
#     'lastsale': '$14.91',
#     'netchange': '-0.20',
#     'pctchange': '-1.324%',
#     'volume': '70322',
#     'marketCap': '10152322147.00',
#     'country': 'China',
#     'ipoyear': '2001',
#     'industry': 'Aluminum',
#     'sector': 'Basic Industries',
#     'url': '/market-activity/stocks/ach'},
#    {'symbol': 'ACHC',
#     'name': 'Acadia Healthcare Company Inc. Common Stock',
#     'lastsale': '$61.41',
#     'netchange': '-1.84',
#     'pctchange': '-2.909%',
#     'volume': '311511',
#     'marketCap': '5510877148.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Hospital/Nursing Management',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/achc'},
#    {'symbol': 'ACHL',
#     'name': 'Achilles Therapeutics plc American Depositary Shares',
#     'lastsale': '$6.97',
#     'netchange': '-0.21',
#     'pctchange': '-2.925%',
#     'volume': '47056',
#     'marketCap': '283133604.00',
#     'country': 'United Kingdom',
#     'ipoyear': '2021',
#     'industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/achl'},
#    {'symbol': 'ACHV',
#     'name': 'Achieve Life Sciences Inc. Common Shares',
#     'lastsale': '$7.90',
#     'netchange': '-0.01',
#     'pctchange': '-0.126%',
#     'volume': '141196',
#     'marketCap': '74655585.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Biotechnology: In Vitro & In Vivo Diagnostic Substances',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/achv'},
#    {'symbol': 'ACI',
#     'name': 'Albertsons Companies Inc. Class A Common Stock',
#     'lastsale': '$19.67',
#     'netchange': '-0.31',
#     'pctchange': '-1.552%',
#     'volume': '645966',
#     'marketCap': '9176270603.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Food Chains',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/aci'},
#    {'symbol': 'ACIC',
#     'name': 'Atlas Crest Investment Corp. Class A Common Stock',
#     'lastsale': '$9.91',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '534628',
#     'marketCap': '619375000.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acic'},
#    {'symbol': 'ACII',
#     'name': 'Atlas Crest Investment Corp. II Class A Common Stock',
#     'lastsale': '$9.76',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '5188',
#     'marketCap': '420900000.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acii'},
#    {'symbol': 'ACIU',
#     'name': 'AC Immune SA Common Stock',
#     'lastsale': '$7.88',
#     'netchange': '-0.36',
#     'pctchange': '-4.369%',
#     'volume': '237285',
#     'marketCap': '572502914.00',
#     'country': 'Switzerland',
#     'ipoyear': '2016',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/aciu'},
#    {'symbol': 'ACIW',
#     'name': 'ACI Worldwide Inc. Common Stock',
#     'lastsale': '$36.55',
#     'netchange': '-0.50',
#     'pctchange': '-1.35%',
#     'volume': '214910',
#     'marketCap': '4317818936.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Computer Software: Prepackaged Software',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/aciw'},
#    {'symbol': 'ACKIT',
#     'name': 'Ackrell SPAC Partners I Co. Subunits',
#     'lastsale': '$9.95',
#     'netchange': '-0.016',
#     'pctchange': '-0.161%',
#     'volume': '101',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/ackit'},
#    {'symbol': 'ACKIU',
#     'name': 'Ackrell SPAC Partners I Co. Units',
#     'lastsale': '$10.24',
#     'netchange': '-0.0101',
#     'pctchange': '-0.099%',
#     'volume': '190',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/ackiu'},
#    {'symbol': 'ACKIW',
#     'name': 'Ackrell SPAC Partners I Co. Warrants',
#     'lastsale': '$0.65',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '17933',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/ackiw'},
#    {'symbol': 'ACLS',
#     'name': 'Axcelis Technologies Inc. Common Stock',
#     'lastsale': '$37.33',
#     'netchange': '-0.96',
#     'pctchange': '-2.507%',
#     'volume': '143318',
#     'marketCap': '1254284155.00',
#     'country': 'United States',
#     'ipoyear': '2000',
#     'industry': 'Industrial Machinery/Components',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acls'},
#    {'symbol': 'ACM',
#     'name': 'AECOM Common Stock',
#     'lastsale': '$62.50',
#     'netchange': '-0.78',
#     'pctchange': '-1.233%',
#     'volume': '563202',
#     'marketCap': '9149558000.00',
#     'country': 'United States',
#     'ipoyear': '2007',
#     'industry': 'Military/Government/Technical',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acm'},
#    {'symbol': 'ACMR',
#     'name': 'ACM Research Inc. Class A Common Stock',
#     'lastsale': '$81.17',
#     'netchange': '-10.93',
#     'pctchange': '-11.868%',
#     'volume': '778151',
#     'marketCap': '1540836636.00',
#     'country': 'United States',
#     'ipoyear': '2017',
#     'industry': 'Industrial Machinery/Components',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acmr'},
#    {'symbol': 'ACN',
#     'name': 'Accenture plc Class A Ordinary Shares (Ireland)',
#     'lastsale': '$312.63',
#     'netchange': '1.06',
#     'pctchange': '0.34%',
#     'volume': '1570648',
#     'marketCap': '198250135887.00',
#     'country': 'Ireland',
#     'ipoyear': '2001',
#     'industry': 'Business Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/acn'},
#    {'symbol': 'ACNB',
#     'name': 'ACNB Corporation Common Stock',
#     'lastsale': '$28.25',
#     'netchange': '0.31',
#     'pctchange': '1.11%',
#     'volume': '22873',
#     'marketCap': '246199315.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acnb'},
#    {'symbol': 'ACND',
#     'name': 'Ascendant Digital Acquisition Corp. Class A Ordinary Shares',
#     'lastsale': '$9.97',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '1839943',
#     'marketCap': '515947500.00',
#     'country': 'United States',
#     'ipoyear': '2020',
#     'industry': 'Computer Software: Prepackaged Software',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acnd'},
#    {'symbol': 'ACOR',
#     'name': 'Acorda Therapeutics Inc. Common Stock',
#     'lastsale': '$4.04',
#     'netchange': '-0.18',
#     'pctchange': '-4.265%',
#     'volume': '114378',
#     'marketCap': '44942661.00',
#     'country': 'United States',
#     'ipoyear': '2006',
#     'industry': 'Biotechnology: Biological Products (No Diagnostic Substances)',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/acor'},
#    {'symbol': 'ACP',
#     'name': 'Aberdeen Income Credit Strategies Fund Common Shares',
#     'lastsale': '$11.24',
#     'netchange': '0.06',
#     'pctchange': '0.537%',
#     'volume': '204237',
#     'marketCap': '195988969.00',
#     'country': 'United States',
#     'ipoyear': '2011',
#     'industry': 'Investment Managers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acp'},
#    {'symbol': 'ACP^A',
#     'name': 'Aberdeen Income Credit Strategies Fund 5.250% Series A Perpetual Preferred Stock',
#     'lastsale': '$26.64',
#     'netchange': '-0.04',
#     'pctchange': '-0.15%',
#     'volume': '12531',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acp^a'},
#    {'symbol': 'ACQR',
#     'name': 'Independence Holdings Corp. Class A Ordinary Share',
#     'lastsale': '$9.8499',
#     'netchange': '0.0399',
#     'pctchange': '0.407%',
#     'volume': '72601',
#     'marketCap': '610581856.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acqr'},
#    {'symbol': 'ACQRU',
#     'name': 'Independence Holdings Corp. Units',
#     'lastsale': '$9.99',
#     'netchange': '-0.01',
#     'pctchange': '-0.10%',
#     'volume': '10280',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acqru'},
#    {'symbol': 'ACQRW',
#     'name': 'Independence Holdings Corp. Warrant',
#     'lastsale': '$1.25',
#     'netchange': '0.05',
#     'pctchange': '4.167%',
#     'volume': '24018',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acqrw'},
#    {'symbol': 'ACR',
#     'name': 'ACRES Commercial Realty Corp. Common Stock',
#     'lastsale': '$15.98',
#     'netchange': '-0.62',
#     'pctchange': '-3.735%',
#     'volume': '47727',
#     'marketCap': '147822207.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acr'},
#    {'symbol': 'ACR^C',
#     'name': 'ACRES Commercial Realty Corp. 8.625% Fixed-to-Floating Series C Cumulative Redeemable Preferred Stock ',
#     'lastsale': '$25.17',
#     'netchange': '-0.12',
#     'pctchange': '-0.474%',
#     'volume': '2672',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acr^c'},
#    {'symbol': 'ACR^D',
#     'name': 'ACRES Commercial Realty Corp. 7.875% Series D Cumulative Redeemable Preferred Stock',
#     'lastsale': '$25.18',
#     'netchange': '-0.09',
#     'pctchange': '-0.356%',
#     'volume': '17533',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acr^d'},
#    {'symbol': 'ACRE',
#     'name': 'Ares Commercial Real Estate Corporation Common Stock',
#     'lastsale': '$14.95',
#     'netchange': '-0.35',
#     'pctchange': '-2.288%',
#     'volume': '551675',
#     'marketCap': '702666759.00',
#     'country': 'United States',
#     'ipoyear': '2012',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/acre'},
#    {'symbol': 'ACRS',
#     'name': 'Aclaris Therapeutics Inc. Common Stock',
#     'lastsale': '$16.85',
#     'netchange': '-0.86',
#     'pctchange': '-4.856%',
#     'volume': '388523',
#     'marketCap': '996670912.00',
#     'country': 'United States',
#     'ipoyear': '2015',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/acrs'},
#    {'symbol': 'ACRX',
#     'name': 'AcelRx Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$1.22',
#     'netchange': '-0.02',
#     'pctchange': '-1.613%',
#     'volume': '1111845',
#     'marketCap': '145305659.00',
#     'country': 'United States',
#     'ipoyear': '2011',
#     'industry': 'Specialty Chemicals',
#     'sector': 'Consumer Durables',
#     'url': '/market-activity/stocks/acrx'},
#    {'symbol': 'ACST',
#     'name': 'Acasti Pharma Inc. Class A Common Stock',
#     'lastsale': '$0.5215',
#     'netchange': '-0.0316',
#     'pctchange': '-5.713%',
#     'volume': '5737947',
#     'marketCap': '50529458.00',
#     'country': 'Canada',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acst'},
#    {'symbol': 'ACTD',
#     'name': 'ArcLight Clean Transition Corp. II Class A Ordinary Share',
#     'lastsale': '$9.94',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '117',
#     'marketCap': '342308750.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/actd'},
#    {'symbol': 'ACTDU',
#     'name': 'ArcLight Clean Transition Corp. II Unit',
#     'lastsale': '$10.1001',
#     'netchange': '0.0101',
#     'pctchange': '0.10%',
#     'volume': '801',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/actdu'},
#    {'symbol': 'ACTDW',
#     'name': 'ArcLight Clean Transition Corp. II Warrant',
#     'lastsale': '$1.5717',
#     'netchange': '0.0417',
#     'pctchange': '2.725%',
#     'volume': '5800',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/actdw'},
#    {'symbol': 'ACTG',
#     'name': 'Acacia Research Corporation (Acacia Tech) Common Stock',
#     'lastsale': '$6.07',
#     'netchange': '-0.03',
#     'pctchange': '-0.492%',
#     'volume': '155367',
#     'marketCap': '299126280.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Multi-Sector Companies',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/actg'},
#    {'symbol': 'ACU',
#     'name': 'Acme United Corporation. Common Stock',
#     'lastsale': '$42.29',
#     'netchange': '-0.03',
#     'pctchange': '-0.071%',
#     'volume': '32915',
#     'marketCap': '147318357.00',
#     'country': 'United States',
#     'ipoyear': '1988',
#     'industry': 'Home Furnishings',
#     'sector': 'Consumer Durables',
#     'url': '/market-activity/stocks/acu'},
#    {'symbol': 'ACV',
#     'name': 'Virtus AllianzGI Diversified Income & Convertible Fund Common Shares of Beneficial Interest',
#     'lastsale': '$34.97',
#     'netchange': '-0.33',
#     'pctchange': '-0.935%',
#     'volume': '29551',
#     'marketCap': '362076582.00',
#     'country': 'United States',
#     'ipoyear': '2015',
#     'industry': 'Finance/Investors Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/acv'},
#    {'symbol': 'ACVA',
#     'name': 'ACV Auctions Inc. Class A Common Stock',
#     'lastsale': '$23.03',
#     'netchange': '-0.75',
#     'pctchange': '-3.154%',
#     'volume': '689417',
#     'marketCap': '3558820119.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'EDP Services',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acva'},
#    {'symbol': 'ACXP',
#     'name': 'Acurx Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$5.82',
#     'netchange': '-0.23',
#     'pctchange': '-3.802%',
#     'volume': '627299',
#     'marketCap': '55529545.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/acxp'},
#    {'symbol': 'ACY',
#     'name': 'AeroCentury Corp. Common Stock',
#     'lastsale': '$11.76',
#     'netchange': '0.04',
#     'pctchange': '0.341%',
#     'volume': '785130',
#     'marketCap': '18179596.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Diversified Commercial Services',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/acy'},
#    {'symbol': 'ADAG',
#     'name': 'Adagene Inc. American Depositary Shares',
#     'lastsale': '$16.85',
#     'netchange': '1.685',
#     'pctchange': '11.111%',
#     'volume': '53910',
#     'marketCap': '733276716.00',
#     'country': 'China',
#     'ipoyear': '2021',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adag'},
#    {'symbol': 'ADAP',
#     'name': 'Adaptimmune Therapeutics plc American Depositary Shares',
#     'lastsale': '$3.87',
#     'netchange': '-0.08',
#     'pctchange': '-2.025%',
#     'volume': '422750',
#     'marketCap': '601775015.00',
#     'country': 'United Kingdom',
#     'ipoyear': '2015',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adap'},
#    {'symbol': 'ADBE',
#     'name': 'Adobe Inc. Common Stock',
#     'lastsale': '$605.01',
#     'netchange': '4.81',
#     'pctchange': '0.801%',
#     'volume': '1434586',
#     'marketCap': '288226764000.00',
#     'country': 'United States',
#     'ipoyear': '1986',
#     'industry': 'Computer Software: Prepackaged Software',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/adbe'},
#    {'symbol': 'ADC',
#     'name': 'Agree Realty Corporation Common Stock',
#     'lastsale': '$72.24',
#     'netchange': '-0.71',
#     'pctchange': '-0.973%',
#     'volume': '390708',
#     'marketCap': '4978085346.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Real Estate Investment Trusts',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/adc'},
#    {'symbol': 'ADCT',
#     'name': 'ADC Therapeutics SA Common Shares',
#     'lastsale': '$23.30',
#     'netchange': '-0.80',
#     'pctchange': '-3.32%',
#     'volume': '182636',
#     'marketCap': '1823691000.00',
#     'country': '',
#     'ipoyear': '2020',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adct'},
#    {'symbol': 'ADER',
#     'name': '26 Capital Acquisition Corp. Class A Common Stock',
#     'lastsale': '$9.73',
#     'netchange': '0.01',
#     'pctchange': '0.103%',
#     'volume': '10631',
#     'marketCap': '334468750.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/ader'},
#    {'symbol': 'ADERU',
#     'name': '26 Capital Acquisition Corp. Unit',
#     'lastsale': '$10.24',
#     'netchange': '-0.03',
#     'pctchange': '-0.292%',
#     'volume': '1674',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/aderu'},
#    {'symbol': 'ADERW',
#     'name': '26 Capital Acquisition Corp. Warrant',
#     'lastsale': '$1.04',
#     'netchange': '-0.03',
#     'pctchange': '-2.804%',
#     'volume': '62769',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/aderw'},
#    {'symbol': 'ADES',
#     'name': 'Advanced Emissions Solutions Inc. Common Stock',
#     'lastsale': '$6.88',
#     'netchange': '-0.24',
#     'pctchange': '-3.371%',
#     'volume': '145518',
#     'marketCap': '129726576.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Industrial Specialties',
#     'sector': 'Basic Industries',
#     'url': '/market-activity/stocks/ades'},
#    {'symbol': 'ADEX',
#     'name': 'Adit EdTech Acquisition Corp. Common Stock',
#     'lastsale': '$9.67',
#     'netchange': '0.01',
#     'pctchange': '0.104%',
#     'volume': '21296',
#     'marketCap': '333615000.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/adex'},
#    {'symbol': 'ADF',
#     'name': 'Aldel Financial Inc. Class A Common Stock',
#     'lastsale': '$9.8057',
#     'netchange': '-0.0043',
#     'pctchange': '-0.044%',
#     'volume': '2752',
#     'marketCap': '146570701.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/adf'},
#    {'symbol': 'ADFI',
#     'name': 'Anfield Dynamic Fixed Income ETF',
#     'lastsale': '$9.7507',
#     'netchange': '-0.0044',
#     'pctchange': '-0.045%',
#     'volume': '1560',
#     'marketCap': '',
#     'country': '',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/adfi'},
#    {'symbol': 'ADI',
#     'name': 'Analog Devices Inc. Common Stock',
#     'lastsale': '$167.26',
#     'netchange': '-0.29',
#     'pctchange': '-0.173%',
#     'volume': '2127121',
#     'marketCap': '61689990305.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Semiconductors',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/adi'},
#    {'symbol': 'ADIL',
#     'name': 'Adial Pharmaceuticals Inc Common Stock',
#     'lastsale': '$2.62',
#     'netchange': '-0.12',
#     'pctchange': '-4.38%',
#     'volume': '353539',
#     'marketCap': '47693230.00',
#     'country': 'United States',
#     'ipoyear': '2018',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adil'},
#    {'symbol': 'ADILW',
#     'name': 'Adial Pharmaceuticals Inc Warrant',
#     'lastsale': '$0.7898',
#     'netchange': '0.0348',
#     'pctchange': '4.609%',
#     'volume': '3476',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2018',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adilw'},
#    {'symbol': 'ADM',
#     'name': 'Archer-Daniels-Midland Company Common Stock',
#     'lastsale': '$59.24',
#     'netchange': '-0.76',
#     'pctchange': '-1.267%',
#     'volume': '1821763',
#     'marketCap': '33097512996.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Farming/Seeds/Milling',
#     'sector': 'Consumer Non-Durables',
#     'url': '/market-activity/stocks/adm'},
#    {'symbol': 'ADMA',
#     'name': 'ADMA Biologics Inc Common Stock',
#     'lastsale': '$1.45',
#     'netchange': '0.01',
#     'pctchange': '0.694%',
#     'volume': '1694939',
#     'marketCap': '185874961.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adma'},
#    {'symbol': 'ADME',
#     'name': 'Aptus Drawdown Managed Equity ETF',
#     'lastsale': '$40.57',
#     'netchange': '-0.05',
#     'pctchange': '-0.123%',
#     'volume': '82951',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '2016',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/adme'},
#    {'symbol': 'ADMP',
#     'name': 'Adamis Pharmaceuticals Corporation Common Stock',
#     'lastsale': '$0.98',
#     'netchange': '-0.05',
#     'pctchange': '-4.854%',
#     'volume': '2364857',
#     'marketCap': '145908418.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/admp'},
#    {'symbol': 'ADMS',
#     'name': 'Adamas Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$5.21',
#     'netchange': '0.01',
#     'pctchange': '0.192%',
#     'volume': '143486',
#     'marketCap': '236576175.00',
#     'country': 'United States',
#     'ipoyear': '2014',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/adms'},
#    {'symbol': 'ADN',
#     'name': 'Advent Technologies Holdings Inc. Class A Common Stock',
#     'lastsale': '$8.06',
#     'netchange': '-0.76',
#     'pctchange': '-8.617%',
#     'volume': '452475',
#     'marketCap': '164731956.00',
#     'country': 'United States',
#     'ipoyear': '2018',
#     'industry': 'Business Services',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/adn'},
#    {'symbol': 'ADNT',
#     'name': 'Adient plc Ordinary Shares ',
# ...
#     'name': 'Bio-Rad Laboratories Inc. Class A Common Stock',
#     'lastsale': '$664.54',
#     'netchange': '-9.44',
#     'pctchange': '-1.401%',
#     'volume': '105575',
#     'marketCap': '19779112048.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Biotechnology: Laboratory Analytical Instruments',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/bio'},
#    {'symbol': 'BIO/B',
#     'name': 'Bio-Rad Laboratories Inc.',
#     'lastsale': '$675.25',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '19',
#     'marketCap': '',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bio/b'},
#    {'symbol': 'BIOC',
#     'name': 'Biocept Inc. Common Stock',
#     'lastsale': '$3.92',
#     'netchange': '-0.08',
#     'pctchange': '-2.00%',
#     'volume': '99514',
#     'marketCap': '52538043.00',
#     'country': 'United States',
#     'ipoyear': '2014',
#     'industry': 'Biotechnology: Commercial Physical & Biological Resarch',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/bioc'},
#    {'symbol': 'BIOL',
#     'name': 'Biolase Inc. Common Stock',
#     'lastsale': '$0.6105',
#     'netchange': '-0.0295',
#     'pctchange': '-4.609%',
#     'volume': '1328390',
#     'marketCap': '91818687.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Medical/Dental Instruments',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/biol'},
#    {'symbol': 'BIOT',
#     'name': 'Biotech Acquisition Company Class A Ordinary Shares',
#     'lastsale': '$9.71',
#     'netchange': '0.02',
#     'pctchange': '0.206%',
#     'volume': '967',
#     'marketCap': '279162500.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/biot'},
#    {'symbol': 'BIOTU',
#     'name': 'Biotech Acquisition Company Unit',
#     'lastsale': '$10.05',
#     'netchange': '-0.02',
#     'pctchange': '-0.199%',
#     'volume': '1101',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/biotu'},
#    {'symbol': 'BIOTW',
#     'name': 'Biotech Acquisition Company Warrant',
#     'lastsale': '$0.80',
#     'netchange': '-0.03',
#     'pctchange': '-3.614%',
#     'volume': '1405',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2021',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/biotw'},
#    {'symbol': 'BIOX',
#     'name': 'Bioceres Crop Solutions Corp. Ordinary Shares',
#     'lastsale': '$13.45',
#     'netchange': '-0.37',
#     'pctchange': '-2.677%',
#     'volume': '31446',
#     'marketCap': '542382373.00',
#     'country': 'Argentina',
#     'ipoyear': '',
#     'industry': 'Business Services',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/biox'},
#    {'symbol': 'BIP',
#     'name': 'Brookfield Infrastructure Partners LP Limited Partnership Units',
#     'lastsale': '$55.90',
#     'netchange': '0.05',
#     'pctchange': '0.09%',
#     'volume': '283773',
#     'marketCap': '16520604610.00',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': 'Power Generation',
#     'sector': 'Public Utilities',
#     'url': '/market-activity/stocks/bip'},
#    {'symbol': 'BIP^A',
#     'name': 'Brookfield Infrastructure Partners LP 5.125% Class A Preferred Limited Partnership Units Series 13',
#     'lastsale': '$26.35',
#     'netchange': '-0.21',
#     'pctchange': '-0.791%',
#     'volume': '8539',
#     'marketCap': '',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bip^a'},
#    {'symbol': 'BIP^B',
#     'name': 'Brookfield Infrastructure Partners LP 5.000% Class A Preferred Limited Partnership Units Series 14',
#     'lastsale': '$25.80',
#     'netchange': '-0.21',
#     'pctchange': '-0.807%',
#     'volume': '15447',
#     'marketCap': '',
#     'country': 'Bermuda',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bip^b'},
#    {'symbol': 'BIPC',
#     'name': 'Brookfield Infrastructure Partners LP Class A Subordinate Voting Shares ',
#     'lastsale': '$75.82',
#     'netchange': '-2.07',
#     'pctchange': '-2.658%',
#     'volume': '150147',
#     'marketCap': '3408137963.00',
#     'country': '',
#     'ipoyear': '2020',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bipc'},
#    {'symbol': 'BIPH',
#     'name': 'Brookfield Infrastructure Corporation 5.000% Subordinated Notes due 2081',
#     'lastsale': '$25.62',
#     'netchange': '-0.06',
#     'pctchange': '-0.234%',
#     'volume': '106327',
#     'marketCap': '0.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': 'Medical/Dental Instruments',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/biph'},
#    {'symbol': 'BIT',
#     'name': 'BlackRock Multi-Sector Income Trust Common Shares of Beneficial Interest',
#     'lastsale': '$18.74',
#     'netchange': '0.07',
#     'pctchange': '0.375%',
#     'volume': '108776',
#     'marketCap': '703837407.00',
#     'country': '',
#     'ipoyear': '2013',
#     'industry': 'Trusts Except Educational Religious and Charitable',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bit'},
#    {'symbol': 'BITE',
#     'name': 'Bite Acquisition Corp. Common Stock',
#     'lastsale': '$9.66',
#     'netchange': '0.00',
#     'pctchange': '0.00%',
#     'volume': '4710',
#     'marketCap': '247682400.00',
#     'country': '',
#     'ipoyear': '2021',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bite'},
#    {'symbol': 'BITF',
#     'name': 'Bitfarms Ltd. Common Stock',
#     'lastsale': '$3.51',
#     'netchange': '-0.31',
#     'pctchange': '-8.115%',
#     'volume': '1499627',
#     'marketCap': '509009193.00',
#     'country': 'Canada',
#     'ipoyear': '',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bitf'},
#    {'symbol': 'BIVI',
#     'name': 'BioVie Inc. Class A Common Stock',
#     'lastsale': '$15.84',
#     'netchange': '0.37',
#     'pctchange': '2.392%',
#     'volume': '41132',
#     'marketCap': '353759852.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/bivi'},
#    {'symbol': 'BJ',
#     'name': "BJ's Wholesale Club Holdings Inc. Common Stock",
#     'lastsale': '$47.82',
#     'netchange': '-0.37',
#     'pctchange': '-0.768%',
#     'volume': '524711',
#     'marketCap': '6557737312.00',
#     'country': 'United States',
#     'ipoyear': '2018',
#     'industry': 'Department/Specialty Retail Stores',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/bj'},
#    {'symbol': 'BJRI',
#     'name': "BJ's Restaurants Inc. Common Stock",
#     'lastsale': '$47.65',
#     'netchange': '-1.19',
#     'pctchange': '-2.437%',
#     'volume': '172314',
#     'marketCap': '1107270925.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Restaurants',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/bjri'},
#    {'symbol': 'BK',
#     'name': 'The Bank of New York Mellon Corporation Common Stock',
#     'lastsale': '$49.96',
#     'netchange': '-0.32',
#     'pctchange': '-0.636%',
#     'volume': '2722332',
#     'marketCap': '43739023116.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bk'},
#    {'symbol': 'BKCC',
#     'name': 'BlackRock Capital Investment Corporation Common Stock',
#     'lastsale': '$3.97',
#     'netchange': '-0.03',
#     'pctchange': '-0.75%',
#     'volume': '213999',
#     'marketCap': '294382884.00',
#     'country': 'United States',
#     'ipoyear': '2007',
#     'industry': 'Investment Managers',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bkcc'},
#    {'symbol': 'BKD',
#     'name': 'Brookdale Senior Living Inc. Common Stock',
#     'lastsale': '$8.43',
#     'netchange': '-0.16',
#     'pctchange': '-1.863%',
#     'volume': '1196481',
#     'marketCap': '1560950636.00',
#     'country': 'United States',
#     'ipoyear': '2005',
#     'industry': 'Hospital/Nursing Management',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/bkd'},
#    {'symbol': 'BKE',
#     'name': 'Buckle Inc. (The) Common Stock',
#     'lastsale': '$46.70',
#     'netchange': '-1.16',
#     'pctchange': '-2.424%',
#     'volume': '321523',
#     'marketCap': '2325141210.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Clothing/Shoe/Accessory Stores',
#     'sector': 'Consumer Services',
#     'url': '/market-activity/stocks/bke'},
#    {'symbol': 'BKEP',
#     'name': 'Blueknight Energy Partners L.P. Common Units',
#     'lastsale': '$3.61',
#     'netchange': '0.02',
#     'pctchange': '0.557%',
#     'volume': '30974',
#     'marketCap': '149699931.00',
#     'country': 'United States',
#     'ipoyear': '2011',
#     'industry': 'Oil & Gas Production',
#     'sector': 'Energy',
#     'url': '/market-activity/stocks/bkep'},
#    {'symbol': 'BKEPP',
#     'name': 'Blueknight Energy Partners L.P. Series A Preferred Units',
#     'lastsale': '$8.15',
#     'netchange': '-0.033',
#     'pctchange': '-0.403%',
#     'volume': '8186',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Oil & Gas Production',
#     'sector': 'Energy',
#     'url': '/market-activity/stocks/bkepp'},
#    {'symbol': 'BKH',
#     'name': 'Black Hills Corporation Common Stock',
#     'lastsale': '$66.09',
#     'netchange': '-0.72',
#     'pctchange': '-1.078%',
#     'volume': '222087',
#     'marketCap': '4155192437.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Electric Utilities: Central',
#     'sector': 'Public Utilities',
#     'url': '/market-activity/stocks/bkh'},
#    {'symbol': 'BKI',
#     'name': 'Black Knight Inc. Common Stock ',
#     'lastsale': '$78.98',
#     'netchange': '-1.30',
#     'pctchange': '-1.619%',
#     'volume': '811485',
#     'marketCap': '12369359662.00',
#     'country': '',
#     'ipoyear': '2017',
#     'industry': 'EDP Services',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/bki'},
#    {'symbol': 'BKN',
#     'name': 'BlackRock Investment Quality Municipal Trust Inc. (The)',
#     'lastsale': '$18.49',
#     'netchange': '-0.02',
#     'pctchange': '-0.108%',
#     'volume': '29449',
#     'marketCap': '318158965.00',
#     'country': 'United States',
#     'ipoyear': '1993',
#     'industry': 'Trusts Except Educational Religious and Charitable',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bkn'},
#    {'symbol': 'BKNG',
#     'name': 'Booking Holdings Inc. Common Stock',
#     'lastsale': '$2188.44',
#     'netchange': '-15.56',
#     'pctchange': '-0.706%',
#     'volume': '394904',
#     'marketCap': '89841618082.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Other Consumer Services',
#     'sector': 'Transportation',
#     'url': '/market-activity/stocks/bkng'},
#    {'symbol': 'BKR',
#     'name': 'Baker Hughes Company Class A Common Stock',
#     'lastsale': '$22.37',
#     'netchange': '-0.65',
#     'pctchange': '-2.824%',
#     'volume': '6423865',
#     'marketCap': '23300380111.00',
#     'country': '',
#     'ipoyear': '2017',
#     'industry': 'Oilfield Services/Equipment',
#     'sector': 'Energy',
#     'url': '/market-activity/stocks/bkr'},
#    {'symbol': 'BKSC',
#     'name': 'Bank of South Carolina Corp. Common Stock',
#     'lastsale': '$20.49',
#     'netchange': '0.44',
#     'pctchange': '2.195%',
#     'volume': '3494',
#     'marketCap': '113199382.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Major Banks',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bksc'},
#    {'symbol': 'BKT',
#     'name': 'BlackRock Income Trust Inc. (The)',
#     'lastsale': '$6.39',
#     'netchange': '0.02',
#     'pctchange': '0.314%',
#     'volume': '191404',
#     'marketCap': '407886831.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Trusts Except Educational Religious and Charitable',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bkt'},
#    {'symbol': 'BKTI',
#     'name': 'BK Technologies Corporation Common Stock',
#     'lastsale': '$3.19',
#     'netchange': '-0.01',
#     'pctchange': '-0.313%',
#     'volume': '40755',
#     'marketCap': '53546450.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Radio And Television Broadcasting And Communications Equipment',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/bkti'},
#    {'symbol': 'BKU',
#     'name': 'BankUnited Inc. Common Stock',
#     'lastsale': '$41.17',
#     'netchange': '-1.57',
#     'pctchange': '-3.673%',
#     'volume': '764477',
#     'marketCap': '3838806529.00',
#     'country': 'United States',
#     'ipoyear': '2011',
#     'industry': 'Savings Institutions',
#     'sector': 'Finance',
#     'url': '/market-activity/stocks/bku'},
#    {'symbol': 'BKYI',
#     'name': 'BIO-key International Inc. Common Stock',
#     'lastsale': '$3.54',
#     'netchange': '0.04',
#     'pctchange': '1.143%',
#     'volume': '376342',
#     'marketCap': '27684411.00',
#     'country': 'United States',
#     'ipoyear': '',
#     'industry': 'Diversified Manufacture',
#     'sector': 'Miscellaneous',
#     'url': '/market-activity/stocks/bkyi'},
#    {'symbol': 'BL',
#     'name': 'BlackLine Inc. Common Stock',
#     'lastsale': '$112.88',
#     'netchange': '-0.96',
#     'pctchange': '-0.843%',
#     'volume': '138846',
#     'marketCap': '6552279099.00',
#     'country': 'United States',
#     'ipoyear': '2016',
#     'industry': 'Computer Software: Prepackaged Software',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/bl'},
#    {'symbol': 'BLBD',
#     'name': 'Blue Bird Corporation Common Stock',
#     'lastsale': '$23.44',
#     'netchange': '-0.24',
#     'pctchange': '-1.014%',
#     'volume': '67861',
#     'marketCap': '636486760.00',
#     'country': 'United States',
#     'ipoyear': '2014',
#     'industry': 'Construction/Ag Equipment/Trucks',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/blbd'},
#    {'symbol': 'BLCM',
#     'name': 'Bellicum Pharmaceuticals Inc. Common Stock',
#     'lastsale': '$3.32',
#     'netchange': '-0.33',
#     'pctchange': '-9.041%',
#     'volume': '119605',
#     'marketCap': '27880706.00',
#     'country': 'United States',
#     'ipoyear': '2014',
#     'industry': 'Major Pharmaceuticals',
#     'sector': 'Health Care',
#     'url': '/market-activity/stocks/blcm'},
#    {'symbol': 'BLCT',
#     'name': 'BlueCity Holdings Limited American Depositary Shares',
#     'lastsale': '$7.49',
#     'netchange': '0.19',
#     'pctchange': '2.603%',
#     'volume': '130798',
#     'marketCap': '268425856.00',
#     'country': 'China',
#     'ipoyear': '2020',
#     'industry': 'EDP Services',
#     'sector': 'Technology',
#     'url': '/market-activity/stocks/blct'},
#    {'symbol': 'BLD',
#     'name': 'TopBuild Corp. Common Stock',
#     'lastsale': '$183.35',
#     'netchange': '-6.27',
#     'pctchange': '-3.307%',
#     'volume': '271960',
#     'marketCap': '6061807323.00',
#     'country': 'United States',
#     'ipoyear': '2015',
#     'industry': 'Engineering & Construction',
#     'sector': 'Capital Goods',
#     'url': '/market-activity/stocks/bld'},
#    {'symbol': 'BLDE',
#     'name': 'Blade Air Mobility Inc. Class A Common Stock',
#     'lastsale': '$8.45',
#     'netchange': '-0.55',
#     'pctchange': '-6.111%',
#     'volume': '1002260',
#     'marketCap': '584851498.00',
#     'country': 'United States',
#     'ipoyear': '2019',
#     'industry': 'Aerospace',
#     'sector': 'Transportation',
#     'url': '/market-activity/stocks/blde'},
#    {'symbol': 'BLDEW',
#     'name': 'Blade Air Mobility Inc. Warrants',
#     'lastsale': '$1.93',
#     'netchange': '-0.17',
#     'pctchange': '-8.095%',
#     'volume': '43669',
#     'marketCap': '0.00',
#     'country': 'United States',
#     'ipoyear': '2019',
#     'industry': '',
#     'sector': '',
#     'url': '/market-activity/stocks/bldew'},
#    ...]},
#  'message': None,
#  'status': {'rCode': 200, 'bCodeMessage': None, 'developerMessage': None}}

# %%
# extract list of unique countries from json file ticker_dict
countries = list(set([x["country"] for x in ticker_dict["data"]["rows"]]))

# extract symbols from the json file ticker_dict for companies listed in the USA
tickers = [x["symbol"] for x in ticker_dict["data"]["rows"] if x["country"] == "United States"]

# extract company names from ticker_dict for companies listed in the USA
names = [x["name"] for x in ticker_dict["data"]["rows"] if x["country"] == "United States"]

# %%
# data source URLs (company financial data and stock stats), using Yahoo Finance
url_financials = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-financials"
url_stats = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-statistics"

# define the region
region = "US"

# %%
def ticker_info(url, symbol):
    querystring = {"symbol": symbol, 
                   "region": region}
    headers = {"x-rapidapi-key": x_rapidapi_key,
               "x-rapidapi-host": x_rapidapi_host}
    try:
        response = requests.get(url = url, 
                                headers = headers, 
                                params = querystring,
                                timeout = 5)
    except Timeout:    
        print("The request has timed out")
    else:
        return response.json()

# %%
# get financial information about AAPL (Apple Inc) using the ticker_info function
# to find out what information to use
financials = ticker_info(url_financials, "AAPL")

# %%
# determine the keys in the json output (dictionary)
financials.keys()
# Out:
# dict_keys(['financialsTemplate', 'cashflowStatementHistory', 'balanceSheetHistoryQuarterly', 'earnings', 'price', 'incomeStatementHistoryQuarterly', 'incomeStatementHistory', 'balanceSheetHistory', 'cashflowStatementHistoryQuarterly', 'quoteType', 'summaryDetail', 'symbol', 'pageViews', 'timeSeries', 'meta', 'loading', 'errorList'])

# %%
def cashflow_df(ticker):
    """ Generates a dataframe containing information from cash flow statements """ 
    # Get financial information using the ticker_info function from Yahoo Finance
    financials = ticker_info(url_financials, ticker)
    
    # Extract selected keys and values and put them in lists
    cashflow = []
    for x in financials["cashflowStatementHistory"]["cashflowStatements"]:
        keys = []
        values = []
        for key, value in x.items():
            keys.append(key)
            if isinstance(value, dict):
                if key == "endDate":
                    values.append(value.get("fmt"))
                else:    
                    values.append(value.get("raw"))
            else:
                values.append(value)

        # Create dictionary containing keys and values   
        dict_ = {key: value for key, value in zip(keys, values)}
        cashflow.append(dict_)

    # Convert the dictionary into a dataframe
    df = pd.DataFrame(cashflow)
    df["endDate"] = [x[0:4] for x in df["endDate"]]
    df["ticker"] = ticker
    return df

# %%
def earnings_df(ticker):
    """ Generates a dataframe containing information from earnings statements """
    # Get financial information using the ticker_info function from Yahoo Finance
    financials = ticker_info(url_financials, ticker)
    
    # Extract annual earnings information from Yahoo Finance
    earnings = []
    for x in financials["earnings"]["financialsChart"]["yearly"]:
        keys = []
        values = []
        for key, value in x.items():
            keys.append(key)
            if isinstance(value, dict):
                values.append(value.get("raw"))
            else:
                values.append(value)

        # Convert earnings information into dictionary
        dict_ = {key:value for key,value in zip(keys,values)}
        earnings.append(dict_)

    # Convert list of dictionaries to pandas dataframe
    df = pd.DataFrame(earnings)
    df["ticker"] = ticker
    return df

# %%
def income_df(ticker):
    """ Generates a dataframe containing information from income statements """
    # Get financial information using the ticker_info function from Yahoo Finance
    financials = ticker_info(url_financials, ticker)
    
    # Extract annual income statement data from Yahoo Finance
    incomes = []
    for x in financials["incomeStatementHistory"]["incomeStatementHistory"]:
        keys = []
        values = []
        for key, value in x.items():
            keys.append(key)
            if isinstance(value, dict):
                if key == "endDate":
                    values.append(value.get("fmt"))
                else:   
                    values.append(value.get("raw"))
            else:
                values.append(value)

         # Convert income statement information into dictionary
        dict_ = {key:value for key,value in zip(keys,values)}
        incomes.append(dict_)

    # Convert list of dictionaries to pandas dataframe
    df = pd.DataFrame(incomes)
    df["endDate"] = [x[0:4] for x in df["endDate"]]
    df["ticker"] = ticker
    return df

# %%
def balance_df(ticker):
    """ Generates a dataframe containing information from income statements """
    # Get financial information using the ticker_info function from Yahoo Finance
    financials = ticker_info(url_financials, ticker)
    
    # Extract annual balance statement data from Yahoo Finance
    balances = []
    for x in financials["balanceSheetHistory"]["balanceSheetStatements"]:
        keys = []
        values = []
        for key, value in x.items():
            keys.append(key)
            if isinstance(value, dict):
                if key == "endDate":
                    values.append(value.get("fmt"))
                else:    
                    values.append(value.get("raw"))
            else:
                values.append(value)

        # Convert balance sheet information into dictionary
        dict_ = {key:value for key,value in zip(keys,values)}
        balances.append(dict_)

    # Convert list of dictionaries into pandas dataframe
    df = pd.DataFrame(balances)
    df["endDate"] = [x[0:4] for x in df["endDate"]]
    df["ticker"] = ticker
    return df

# %%
cashflow_df("AVGO").columns
# Out:
# Index(['changeToLiabilities', 'totalCashflowsFromInvestingActivities',
#        'netBorrowings', 'totalCashFromFinancingActivities',
#        'changeToOperatingActivities', 'issuanceOfStock', 'netIncome',
#        'changeInCash', 'endDate', 'repurchaseOfStock',
#        'totalCashFromOperatingActivities', 'depreciation',
#        'otherCashflowsFromInvestingActivities', 'dividendsPaid',
#        'changeToInventory', 'changeToAccountReceivables',
#        'otherCashflowsFromFinancingActivities', 'maxAge', 'changeToNetincome',
#        'capitalExpenditures', 'investments', 'ticker'],
#       dtype='object')

# %%
earnings_df = earnings_df("AVGO")
earnings_df
# Out:
#    date      revenue     earnings ticker
# 0  2017  17636000000   1692000000   AVGO
# 1  2018  20848000000  12259000000   AVGO
# 2  2019  22597000000   2724000000   AVGO
# 3  2020  23888000000   2960000000   AVGO

# %%
income_df("AVGO").columns
# Out:
# Index(['researchDevelopment', 'effectOfAccountingCharges', 'incomeBeforeTax',
#        'minorityInterest', 'netIncome', 'sellingGeneralAdministrative',
#        'grossProfit', 'ebit', 'endDate', 'operatingIncome',
#        'otherOperatingExpenses', 'interestExpense', 'extraordinaryItems',
#        'nonRecurring', 'otherItems', 'incomeTaxExpense', 'totalRevenue',
#        'totalOperatingExpenses', 'costOfRevenue', 'totalOtherIncomeExpenseNet',
#        'maxAge', 'discontinuedOperations', 'netIncomeFromContinuingOps',
#        'netIncomeApplicableToCommonShares', 'ticker'],
#       dtype='object')

# %%
# Create a dataframe containing income of a specific ticker
income_df = income_df("AVGO")

# Create a list of cost of goods sold (formula: COGS = gross profit - revenue)
cogs = list(income_df["grossProfit"] - income_df["totalRevenue"])

# Calculate proportion of COGS in terms of total revenue
cogs_pct = [(cogs[x] / income_df["totalRevenue"][x]) * 100 
            for x in range(0,len(income_df["totalRevenue"]))]

# Calculate proportion of operating expenses to total revenue
opex_pct = list((income_df["totalOperatingExpenses"]/ income_df["totalRevenue"]) * 100)

# %%
# Calculate
# Out:
# [82.20864032150034, 80.83373899190158, 73.68092862624712, 84.75277840780223]

# %%
income_df["grossProfit"][0] - income_df["totalRevenue"][0]

# %%
balance_df("AVGO").columns
# Out:
# Index(['intangibleAssets', 'capitalSurplus', 'totalLiab',
#        'totalStockholderEquity', 'otherCurrentLiab', 'totalAssets', 'endDate',
#        'otherCurrentAssets', 'otherLiab', 'goodWill', 'treasuryStock',
#        'otherAssets', 'cash', 'totalCurrentLiabilities',
#        'deferredLongTermAssetCharges', 'shortLongTermDebt',
#        'otherStockholderEquity', 'propertyPlantEquipment',
#        'totalCurrentAssets', 'netTangibleAssets', 'netReceivables', 'maxAge',
#        'longTermDebt', 'inventory', 'accountsPayable', 'commonStock',
#        'retainedEarnings', 'minorityInterest', 'ticker'],
#       dtype='object')

# %%
# Create a list of revenues from the earnings df
actual_revenues = list(earnings_df["revenue"])
actual_years = list(earnings_df["date"])

# Calculate year-on-year revenues growth
yoy_growth = [round((((actual_revenues[i+1] / actual_revenues[i]) - 1) * 100),2) for i in range(0,len(actual_revenues)-1)]
yoy_growth.insert(0, "NA") # first year does not have yoy growth stat

# %%
# Create a list of forecast years (duration: 5 years)
forecast_years = []
for i in range(1, 6):
    fyr = actual_years[-1] + i
    i += 1
    forecast_years.append(fyr)

# %%
# Based on the range of yoy growth, setting the following as forecasted growth rates:
optimistic_case = round(max(yoy_growth[1:]))
base_case = round(sum(yoy_growth[1:])/len(yoy_growth[1:]))
worst_case = round(min(yoy_growth[1:]))

# %%
# Create a function that will calculate revenue growth forecasts 
# based on any of the three growth rates
def forecast_revgrowth(case, revenue):
    growth = round(revenue * ((case / 100) + 1))
    return growth

# %%
def forecast_revgrowth2(case):
    forecast_revenues = []
    for i in range(-1, 4):
        if i < 0:
            growth = forecast_revgrowth(case, actual_revenues[i])
            forecast_revenues.append(growth)
        else:
            growth = forecast_revgrowth(case, forecast_revenues[i])
            forecast_revenues.append(growth)

    return forecast_revenues

# %%
forecast_revgrowth2(base_case)
